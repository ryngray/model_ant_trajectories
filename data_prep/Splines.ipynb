# %%
from scipy import interpolate
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#import Splines as edr
import trackfuns as tf
import copy as copy

# %%
#f = pd.read_csv("ants.txt", delimiter=',')
f = pd.read_csv(r'C:\Users\stpop\Documents\MATLAB\clean_652660_uniqAnts\HRM_T1_ants.txt')

# %%
f1 = f[f['id']==1]

# %%
plt.plot(f1['x'],f1['y'])

# %%
edr = tf.get_edr(f1,s=100)

# %%
met = tf.addMetrics(edr)

# %%
#plt.hist(met.s,range=(0,5),bins=20)
#plt.hist(f1.s,50)
#plt.show()
plt.hist(met.alpha)
np.max(met.s)
# Out:
# 118.79357565474675
